# %%
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Chrome()

# %%
tsherpa_map_search_url = f"https://edu.tsherpa.co.kr/LectureInfo/LectureReviews2"

# %%
driver.get(tsherpa_map_search_url)

# %%
ind = 1
list1 = []

while 1:
    try:
        if driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img').is_displayed():
            pass
        else :
            review = driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0] #연수명
            content = review.split('\n\n')[1].split('\n')[1] # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
            score = img_element.get_attribute('alt')
            date_ = driver.find_element(by='xpath', value = f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1]
            list1.append([title, content, score, date])
            
        ind += 1
    except: 
        break

# %%
list1
# Out:
# []

# %%
ind = 1
list1 = []

while 1:
    try:
        # 해당 인덱스의 요소가 보이는지 확인
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
        if img_element.is_displayed():
            # 이미지가 보일 때의 처리: 데이터를 수집하고 리스트에 추가
            review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0]  # 연수명
            content = review.split('\n\n')[1].split('\n')[1]  # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img') 
            score = img_element.get_attribute('alt') # 별점
            date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1] # 등록일
            list1.append([title, content, score, date])
        
        # 다음 인덱스로 이동
        ind += 1
    except:
        break

# %%
list1
# Out:
# [['30시간 강의의 품격', '비추천합니다. 새로울 것 없는 내용과 화질 안 좋은 것은 참…', '3점', '2023.07.27'],
#  ['30시간 신병주 교수의 왕으로 산다는 것',
#   '조선왕들의 역사를 통하여 현재를 묻는 거울이 된다. 균형…',
#   '5점',
#   '2023.07.27']]

# %%
ind = 1
list1 = []

while 1:
    try:
        # 더보기 관계없이 데이터 수집
        review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
        title = review.split('\n\n')[0]  # 연수명
        content = review.split('\n\n')[1].split('\n')[1]  # 내용
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
        score = img_element.get_attribute('alt')
        date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
        date = date_.split('\n')[1]
        list1.append([title, content, score, date])
        
        # 다음 인덱스로 이동
        ind += 1
    except:
        # 예외가 발생하면(더 이상 데이터가 없으면) 루프 종료
        break

# %%
pd.DataFrame(list1)
# Out:
#                                         0                                   1  \
# 0                             30시간 강의의 품격  비추천합니다. 새로울 것 없는 내용과 화질 안 좋은 것은 참…
# 1                  30시간 신병주 교수의 왕으로 산다는 것    조선왕들의 역사를 통하여 현재를 묻는 거울이 된다. 균형…
# 2            15시간 메디컬 콘서트 1탄 - 현대인의 만성 질병    잘못 알고 있던 의학 상식들을 제대로 알 수 있어 좋았어요
# 3                        15시간 정훈쌤의 뚝딱 칼림바  칼림바 연수에서 칼림바와 악보를 선물로 받았습니다. 학생들이…
# 4                   30시간 지리와 함께하는 인문학 티타임                              감사합니다.
# 5                        30시간 메이슨의 패턴잉글리쉬  그동안 영어 연수 많이 받았었는데, 1강부터 30강까지 이렇…
# 6              30시간 7인의 전문의와 함께하는 메디컬 콘서트  막연한 의학 용어와 지식을 제대로 알게 되는 기회가 되었습니…
# 7  10시간 어린이 생활세계로 열어가는 사회 교과서 이야기 (5~6학년)  5학년을 여러해 담임하고 있습니다. 같은 학년을 반복해 하다…
# 8                     6시간 한 번에 끝내는 법정연수 1  매년 들어야 하는 법정연수이지만 조금이라도 더 귀에 쏙쏙 들…
# 9                   30시간 지리와 함께하는 인문학 티타임                   다양한 구성이 듣기 좋았습니다.
#
#     2           3
# 0  3점  2023.07.27
# 1  5점  2023.07.27
# 2  5점  2023.07.27
# 3  5점  2023.07.26
# 4  5점  2023.07.26
# 5  5점  2023.07.26
# 6  5점  2023.07.25
# 7  5점  2023.07.24
# 8  5점  2023.07.24
# 9  5점  2023.07.24

# %%
ind = 1
list1 = []

while 1:
    try:
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
        if img_element.is_displayed():
            list1.append(["title", content, score, date])
        else:
            review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0]  # 연수명
            content = review.split('\n\n')[1].split('\n')[1]  # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
            score = img_element.get_attribute('alt')
            date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1]
            list1.append([title, content, score, date])
        
        # 다음 인덱스로 이동
        ind += 1
    except Exception as e:
        # 예외가 발생하면(더 이상 데이터가 없으면) 루프 종료
        # 이미지가 있으면 리스트에 들어가는데 없으면 아예 예외처리 되어 그 다음 코드는 실행되지 않는 문제 발생
        # 예외 출력 
        print(f"예외 발생: {e}")
        break
# Out:
# 예외 발생: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mainForm"]/table/tbody/tr[3]/td[2]/a/img"}
#   (Session info: chrome=114.0.5735.248); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0066A813+48355]
# 	(No symbol) [0x005FC4B1]
# 	(No symbol) [0x00505358]
# 	(No symbol) [0x005309A5]
# 	(No symbol) [0x00530B3B]
# 	(No symbol) [0x0055E232]
# 	(No symbol) [0x0054A784]
# 	(No symbol) [0x0055C922]
# 	(No symbol) [0x0054A536]
# 	(No symbol) [0x005282DC]
# 	(No symbol) [0x005293DD]
# 	GetHandleVerifier [0x008CAABD+2539405]
# 	GetHandleVerifier [0x0090A78F+2800735]
# 	GetHandleVerifier [0x0090456C+2775612]
# 	GetHandleVerifier [0x006F51E0+616112]
# 	(No symbol) [0x00605F8C]
# 	(No symbol) [0x00602328]
# 	(No symbol) [0x0060240B]
# 	(No symbol) [0x005F4FF7]
# 	BaseThreadInitThunk [0x76467D59+25]
# 	RtlInitializeExceptionChain [0x76F2B74B+107]
# 	RtlClearBits [0x76F2B6CF+191]

# %%
pd.DataFrame(list1)
# Out:
#        0       1       2       3
# 0  title  나중에 수정  나중에 수정  나중에 수정
# 1  title  나중에 수정  나중에 수정  나중에 수정

# %%
ind = 1
list1 = []

while 1:
    try:
        # 해당 인덱스의 요소가 보이는지 확인
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
        if img_element.is_displayed():
            # 이미지가 보일 때의 처리: 새창이 뜨는데, 일단 어떻게해야할지 보류라서 이 부분은 그냥 빈칸으로 둠 (나중에 수정)
            title = "나중에 수정"
            content = "나중에 수정"
            score = "나중에 수정"
            date = "나중에 수정"
            list1.append([title, content, score, date])
            continue

        else:
            review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0]  # 연수명
            content = review.split('\n\n')[1].split('\n')[1]  # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img') 
            score = img_element.get_attribute('alt') # 별점
            date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1] # 등록일
            list1.append([title, content, score, date])
            
        # 다음 인덱스로 이동
        ind += 1
        
    except:
        break

# %%
pd.DataFrame(list1)
# Out:
#           0       1       2       3
# 0    나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 1    나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 2    나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 3    나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 4    나중에 수정  나중에 수정  나중에 수정  나중에 수정
# ..      ...     ...     ...     ...
# 264  나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 265  나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 266  나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 267  나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 268  나중에 수정  나중에 수정  나중에 수정  나중에 수정
#
# [269 rows x 4 columns]

# %%
# 문제원인추측 
# 이미지가 없으면 아예 코드자체가 존재하지 않음 
# 그럼 if문을 수정해야하는데
# 어떻게 ?

# %%
driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[3]/td[2]/a').is_displayed()
# Out:
# True

# %%
ind = 1
list1 = []

while 1:
    try:
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
        if img_element.is_displayed():
            list1.append(["title", "content", "score", "date"])
        
        # 다음 인덱스로 이동
        ind += 1
        
    except:
        text_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a')
        if text_element.is_displayed():
            review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0]  # 연수명
            content = review.split('\n\n')[1].split('\n')[1]  # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
            score = img_element.get_attribute('alt')
            date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1]
            list1.append([title, content, score, date])
        
        # 다음 인덱스로 이동
            ind += 1
            continue
        
        else:
            break
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[57], line 6
#       5 try:
# ----> 6     img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
#       7     if img_element.is_displayed():
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:740, in WebDriver.find_element(self, by, value)
#     738     value = f'[name="{value}"]'
# --> 740 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mainForm"]/table/tbody/tr[11]/td[2]/a/img"}
#   (Session info: chrome=114.0.5735.248); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0066A813+48355]
# 	(No symbol) [0x005FC4B1]
# 	(No symbol) [0x00505358]
# 	(No symbol) [0x005309A5]
# 	(No symbol) [0x00530B3B]
# 	(No symbol) [0x0055E232]
# 	(No symbol) [0x0054A784]
# 	(No symbol) [0x0055C922]
# 	(No symbol) [0x0054A536]
# 	(No symbol) [0x005282DC]
# 	(No symbol) [0x005293DD]
# 	GetHandleVerifier [0x008CAABD+2539405]
# 	GetHandleVerifier [0x0090A78F+2800735]
# 	GetHandleVerifier [0x0090456C+2775612]
# 	GetHandleVerifier [0x006F51E0+616112]
# 	(No symbol) [0x00605F8C]
# 	(No symbol) [0x00602328]
# 	(No symbol) [0x0060240B]
# 	(No symbol) [0x005F4FF7]
# 	BaseThreadInitThunk [0x76467D59+25]
# 	RtlInitializeExceptionChain [0x76F2B74B+107]
# 	RtlClearBits [0x76F2B6CF+191]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[57], line 14
#      11     ind += 1
#      13 except:
# ---> 14     text_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a')
#      15     if text_element.is_displayed():
#      16         review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:740, in WebDriver.find_element(self, by, value)
#     737     by = By.CSS_SELECTOR
#     738     value = f'[name="{value}"]'
# --> 740 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#     348     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mainForm"]/table/tbody/tr[11]/td[2]/a"}
#   (Session info: chrome=114.0.5735.248); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0066A813+48355]
# 	(No symbol) [0x005FC4B1]
# 	(No symbol) [0x00505358]
# 	(No symbol) [0x005309A5]
# 	(No symbol) [0x00530B3B]
# 	(No symbol) [0x0055E232]
# 	(No symbol) [0x0054A784]
# 	(No symbol) [0x0055C922]
# 	(No symbol) [0x0054A536]
# 	(No symbol) [0x005282DC]
# 	(No symbol) [0x005293DD]
# 	GetHandleVerifier [0x008CAABD+2539405]
# 	GetHandleVerifier [0x0090A78F+2800735]
# 	GetHandleVerifier [0x0090456C+2775612]
# 	GetHandleVerifier [0x006F51E0+616112]
# 	(No symbol) [0x00605F8C]
# 	(No symbol) [0x00602328]
# 	(No symbol) [0x0060240B]
# 	(No symbol) [0x005F4FF7]
# 	BaseThreadInitThunk [0x76467D59+25]
# 	RtlInitializeExceptionChain [0x76F2B74B+107]
# 	RtlClearBits [0x76F2B6CF+191]
