# %%
from selenium import webdriver
import pandas as pd

from selenium.common.exceptions import NoSuchElementException

import time

# %%
driver = webdriver.Chrome()

# %%
tsherpa_map_search_url = "https://edu.tsherpa.co.kr/LectureInfo/LectureReviews2"

# %%
driver.get(tsherpa_map_search_url)

# %%
print(driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/table/tbody/tr[1]/td[2]/a').text)
# Out:
# 30시간 강의의 품격
#
# 솔직히 말씀드리자면 내용도 올드하고 음향은 정말 듣기 힘들었습니다.
# 비추천합니다. 새로울 것 없는 내용과 화질 안 좋은 것은 참…

# %%
ind = 1
list1 = []

while 1:
    try:
        if driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img').is_displayed():
            pass
        else :
            review = driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0] #연수명
            content = review.split('\n\n')[1].split('\n')[1] # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
            score = img_element.get_attribute('alt')
            date_ = driver.find_element(by='xpath', value = f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1]
            list1.append([title, content, score, date])
            
        ind += 1
    except: 
        break

# %%
list1
# Out:
# []

# %%
ind = 1
list1 = []

while 1:
    try:
        # 해당 인덱스의 요소가 보이는지 확인
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
        if img_element.is_displayed():
            # 이미지가 보일 때의 처리: 데이터를 수집하고 리스트에 추가
            review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0]  # 연수명
            content = review.split('\n\n')[1].split('\n')[1]  # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img') 
            score = img_element.get_attribute('alt') # 별점
            date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1] # 등록일
            list1.append([title, content, score, date])
        
        # 다음 인덱스로 이동
        ind += 1
    except:
        break

# %%
list1
# Out:
# [['30시간 강의의 품격', '비추천합니다. 새로울 것 없는 내용과 화질 안 좋은 것은 참…', '3점', '2023.07.27'],
#  ['30시간 신병주 교수의 왕으로 산다는 것',
#   '조선왕들의 역사를 통하여 현재를 묻는 거울이 된다. 균형…',
#   '5점',
#   '2023.07.27']]

# %%
ind = 1
list1 = []

while 1:
    try:
        # 더보기 관계없이 데이터 수집
        review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
        title = review.split('\n\n')[0]  # 연수명
        content = review.split('\n\n')[1].split('\n')[1]  # 내용
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
        score = img_element.get_attribute('alt')
        date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
        date = date_.split('\n')[1]
        list1.append([title, content, score, date])
        
        # 다음 인덱스로 이동
        ind += 1
    except:
        # 예외가 발생하면(더 이상 데이터가 없으면) 루프 종료
        break

# %%
list1
# Out:
# [['30시간 강의의 품격', '비추천합니다. 새로울 것 없는 내용과 화질 안 좋은 것은 참…', '3점', '2023.07.27'],
#  ['30시간 신병주 교수의 왕으로 산다는 것',
#   '조선왕들의 역사를 통하여 현재를 묻는 거울이 된다. 균형…',
#   '5점',
#   '2023.07.27'],
#  ['15시간 메디컬 콘서트 1탄 - 현대인의 만성 질병',
#   '잘못 알고 있던 의학 상식들을 제대로 알 수 있어 좋았어요',
#   '5점',
#   '2023.07.27'],
#  ['15시간 정훈쌤의 뚝딱 칼림바',
#   '칼림바 연수에서 칼림바와 악보를 선물로 받았습니다. 학생들이…',
#   '5점',
#   '2023.07.26'],
#  ['30시간 지리와 함께하는 인문학 티타임', '감사합니다.', '5점', '2023.07.26'],
#  ['30시간 메이슨의 패턴잉글리쉬',
#   '그동안 영어 연수 많이 받았었는데, 1강부터 30강까지 이렇…',
#   '5점',
#   '2023.07.26'],
#  ['30시간 7인의 전문의와 함께하는 메디컬 콘서트',
#   '막연한 의학 용어와 지식을 제대로 알게 되는 기회가 되었습니…',
#   '5점',
#   '2023.07.25'],
#  ['10시간 어린이 생활세계로 열어가는 사회 교과서 이야기 (5~6학년)',
#   '5학년을 여러해 담임하고 있습니다. 같은 학년을 반복해 하다…',
#   '5점',
#   '2023.07.24'],
#  ['6시간 한 번에 끝내는 법정연수 1',
#   '매년 들어야 하는 법정연수이지만 조금이라도 더 귀에 쏙쏙 들…',
#   '5점',
#   '2023.07.24'],
#  ['30시간 지리와 함께하는 인문학 티타임', '다양한 구성이 듣기 좋았습니다.', '5점', '2023.07.24']]

# %%
pd.DataFrame(list1)
# Out:
#                                         0                                   1  \
# 0                             30시간 강의의 품격  비추천합니다. 새로울 것 없는 내용과 화질 안 좋은 것은 참…
# 1                  30시간 신병주 교수의 왕으로 산다는 것    조선왕들의 역사를 통하여 현재를 묻는 거울이 된다. 균형…
# 2            15시간 메디컬 콘서트 1탄 - 현대인의 만성 질병    잘못 알고 있던 의학 상식들을 제대로 알 수 있어 좋았어요
# 3                        15시간 정훈쌤의 뚝딱 칼림바  칼림바 연수에서 칼림바와 악보를 선물로 받았습니다. 학생들이…
# 4                   30시간 지리와 함께하는 인문학 티타임                              감사합니다.
# 5                        30시간 메이슨의 패턴잉글리쉬  그동안 영어 연수 많이 받았었는데, 1강부터 30강까지 이렇…
# 6              30시간 7인의 전문의와 함께하는 메디컬 콘서트  막연한 의학 용어와 지식을 제대로 알게 되는 기회가 되었습니…
# 7  10시간 어린이 생활세계로 열어가는 사회 교과서 이야기 (5~6학년)  5학년을 여러해 담임하고 있습니다. 같은 학년을 반복해 하다…
# 8                     6시간 한 번에 끝내는 법정연수 1  매년 들어야 하는 법정연수이지만 조금이라도 더 귀에 쏙쏙 들…
# 9                   30시간 지리와 함께하는 인문학 티타임                   다양한 구성이 듣기 좋았습니다.
#
#     2           3
# 0  3점  2023.07.27
# 1  5점  2023.07.27
# 2  5점  2023.07.27
# 3  5점  2023.07.26
# 4  5점  2023.07.26
# 5  5점  2023.07.26
# 6  5점  2023.07.25
# 7  5점  2023.07.24
# 8  5점  2023.07.24
# 9  5점  2023.07.24

# %%
pd.DataFrame(list1)
# Out:
#        0                  1   2           3
# 0  title  다양한 구성이 듣기 좋았습니다.  5점  2023.07.24
# 1  title  다양한 구성이 듣기 좋았습니다.  5점  2023.07.24

# %%
ind = 1
list1 = []

while 1:
    try:
        # 해당 인덱스의 요소가 보이는지 확인
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
        if img_element.is_displayed():
            # 이미지가 보일 때의 처리: 새창이 뜨는데, 일단 어떻게해야할지 보류라서 이 부분은 그냥 빈칸으로 둠 (나중에 수정)
            title = "나중에 수정"
            content = "나중에 수정"
            score = "나중에 수정"
            date = "나중에 수정"
            list1.append([title, content, score, date])
            continue

        else:
            review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0]  # 연수명
            content = review.split('\n\n')[1].split('\n')[1]  # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img') 
            score = img_element.get_attribute('alt') # 별점
            date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1] # 등록일
            list1.append([title, content, score, date])
            
        # 다음 인덱스로 이동
        ind += 1
        
    except:
        break

# %%
pd.DataFrame(list1)
# Out:
#           0       1       2       3
# 0    나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 1    나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 2    나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 3    나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 4    나중에 수정  나중에 수정  나중에 수정  나중에 수정
# ..      ...     ...     ...     ...
# 264  나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 265  나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 266  나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 267  나중에 수정  나중에 수정  나중에 수정  나중에 수정
# 268  나중에 수정  나중에 수정  나중에 수정  나중에 수정
#
# [269 rows x 4 columns]

# %%
# 문제원인추측 
# 이미지가 없으면 아예 코드자체가 존재하지 않음 
# 그럼 if문을 수정해야하는데
# 어떻게 ?

# %%
driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[3]/td[2]/a').is_displayed()
# Out:
# True

# %%
from selenium.common.exceptions import NoSuchElementException

ind = 1
list1 = []

while True:
    try:
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
        if img_element.is_displayed():
            list1.append(["title", "content", "score", "date"])
        else:
            review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0]  # 연수명
            content = review.split('\n\n')[1].split('\n')[1]  # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
            score = img_element.get_attribute('alt')
            date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1]
            list1.append([title, content, score, date])
        
        # 다음 인덱스로 이동
        ind += 1
    except NoSuchElementException:
        # 더 이상 데이터가 없으면 루프 종료
        break
    except Exception as e:
        # 다른 예외 처리
        print(f"예외 발생: {e}")
        break

# %%
pd.DataFrame(list1)
# Out:
#        0        1      2     3
# 0  title  content  score  date
# 1  title  content  score  date

# %%
# 한페이지에 플러스가 있는 리뷰와 없는 리뷰를 각각 데이터 수집함

# %%
ind = 1
list1 = []

while True:
    try:
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
        # 이미지가 있는 경우 데이터 수집
        if img_element.is_displayed():
            list1.append(["title", "content", "score", "date"])
    except NoSuchElementException:
        # 이미지가 없는 경우 데이터 수집
        try:
            review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0]  # 연수명
            content = review.split('\n\n')[1].split('\n')[1]  # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
            score = img_element.get_attribute('alt')
            date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1]
            list1.append([title, content, score, date])
        except NoSuchElementException:
            # 더 이상 데이터가 없으면 루프 종료
            break
    except Exception as e:
        # 다른 예외 처리
        print(f"예외 발생: {e}")
        break
    finally:
        # 다음 인덱스로 이동
        ind += 1

# %%
pd.DataFrame(list1)
# Out:
#                               0                                 1      2  \
# 0                         title                           content  score
# 1                         title                           content  score
# 2  15시간 메디컬 콘서트 1탄 - 현대인의 만성 질병  잘못 알고 있던 의학 상식들을 제대로 알 수 있어 좋았어요     5점
# 3                         title                           content  score
# 4         30시간 지리와 함께하는 인문학 티타임                            감사합니다.     5점
# 5                         title                           content  score
# 6                         title                           content  score
# 7                         title                           content  score
# 8                         title                           content  score
# 9         30시간 지리와 함께하는 인문학 티타임                 다양한 구성이 듣기 좋았습니다.     5점
#
#             3
# 0        date
# 1        date
# 2  2023.07.27
# 3        date
# 4  2023.07.26
# 5        date
# 6        date
# 7        date
# 8        date
# 9  2023.07.24

# %%
# 이제 플러스 버튼으로 새창 열어야하는 것도 수집 시작

# %%
ind = 1
list1 = []

while True:
    try:
        img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
        # 이미지가 있는 경우 데이터 수집
        if img_element.is_displayed():
            # 플러스 이미지 클릭 
            driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img').click()
            # 열린 새로운 창으로 이동 
            driver.switch_to.window(driver.window_handles[-1])
            time.sleep(3) # 크롤링할 시간을 줌 

            title = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[1]/span/a').text  # 연수명
            content = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[2]/table/tbody/tr[3]/td').text  # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[2]/table/tbody/tr[2]/td/span[1]/img')
            score = img_element.get_attribute('alt')

            driver.close() # 창 닫음 
            driver.switch_to.window(driver.window_handles[0]) # 다시 현재의 창으로 이동 

            # 등록일은 구성이 밖에서 수집하는게 더 좋아서 밖에서 수집 
            date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1]
            
            # 수집한 데이터를 리스트에 넣음 
            list1.append([title, content, score, date])
            
    except NoSuchElementException:
        # 이미지가 없는 경우 데이터 수집
        try:
            review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
            title = review.split('\n\n')[0]  # 연수명
            content = review.split('\n\n')[1].split('\n')[1]  # 내용
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
            score = img_element.get_attribute('alt') # 점수
            date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
            date = date_.split('\n')[1] # 등록일 
            list1.append([title, content, score, date])
            
        except NoSuchElementException:
            # 더 이상 데이터가 없으면 루프 종료
            break
            
    except Exception as e:
        # 다른 예외 처리
        print(f"예외 발생: {e}")
        break
        
    finally:
        # 다음 인덱스로 이동
        ind += 1

# %%
list1
# Out:
# [['강의의 품격',
#   '비추천합니다. 새로울 것 없는 내용과 화질 안 좋은 것은 참겠는데 음향은 정말 괴로웠어요.',
#   '3점',
#   '2023.07.27'],
#  ['신병주 교수의 왕으로 산다는 것',
#   '조선왕들의 역사를 통하여 현재를 묻는 거울이 된다.\n균형있는 강의 내용과 치우침이 없는 중립적인 관점이 역사를 공부하는 나에게 큰 귀감이 되었다.',
#   '5점',
#   '2023.07.27'],
#  ['15시간 메디컬 콘서트 1탄 - 현대인의 만성 질병',
#   '잘못 알고 있던 의학 상식들을 제대로 알 수 있어 좋았어요',
#   '5점',
#   '2023.07.27'],
#  ['정훈쌤의 뚝딱 칼림바',
#   '칼림바 연수에서 칼림바와 악보를 선물로 받았습니다. 학생들이 음악 강사와 칼림바 수업을 할 때 별 생각 없이 교실에 앉아 있었는데 이번에 티셀파 연수원에 수업이 있어서 수강하게 되었습니다.칼림바에 대해서 알고 간단한 연주도 하고 반주를 넣어서^^ 연주도 할 수 있게 되어 신기했어요. 강사님이 연주 하시는 곡을 들으며 요즘 마음이 많이 다운되어 있었는데 힐링 되는 느낌이었구요. 천천히 또 친절하게 알려주시고 연주해 주셔서 부담없이 들을 수 있는 좋은 강의였습니다.',
#   '5점',
#   '2023.07.26'],
#  ['30시간 지리와 함께하는 인문학 티타임', '감사합니다.', '5점', '2023.07.26'],
#  ['메이슨의 패턴잉글리쉬',
#   '그동안 영어 연수 많이 받았었는데, 1강부터 30강까지 이렇게 열심히 들은 연수는 없었던 것 같아요. 패턴을 따라하다보면 뭔가 막 잘 말할수 있을것 같고 그런 느낌이 들었습니다. 몇 번 더 복습하면 저도 자연스럽게 대화할수 있겠죠???',
#   '5점',
#   '2023.07.26'],
#  ['7인의 전문의와 함께하는 메디컬 콘서트',
#   '막연한 의학 용어와 지식을 제대로 알게 되는 기회가 되었습니다. 들은 내용을 토대로 건강 관리에 힘쓰겠습니다. 감사합니다.',
#   '5점',
#   '2023.07.25'],
#  ['어린이 생활세계로 열어가는 사회 교과서 이야기 (5~6학년)',
#   '5학년을 여러해 담임하고 있습니다. 같은 학년을 반복해 하다보니 사회 과목은 아주 잘 가르칠 것 같지만... 꼭 그렇지도 않네요. 다양한고 재미있는 활동 중심으로 업그레이드 하고 싶어 이 연수를 듣게 되었습니다. 역시 듣기를 잘 했네요. 배움은 끝이 없는 것 같습니다. ^^ 감사합니다!',
#   '5점',
#   '2023.07.24'],
#  ['한 번에 끝내는 법정연수 1',
#   '매년 들어야 하는 법정연수이지만 조금이라도 더 귀에 쏙쏙 들어오게 해 주는 강의가 감사합니다. T셀파는 그런 면을 잘 고려하여 만들어 주시네요. 이왕이면 귀에 쏙쏙! 머리에 쏙쏙! 들어오도록 구성을 만들고 강의력 좋은 강사님이 좋죠! T셀파 감사합니다. ^^',
#   '5점',
#   '2023.07.24'],
#  ['30시간 지리와 함께하는 인문학 티타임', '다양한 구성이 듣기 좋았습니다.', '5점', '2023.07.24']]

# %%
# 이제 반복문을 돌려 다음페이지로 넘어가는거를 도전

# %%
ind = 1  # 현재 복사한 순서 # 인덱스
no = 1  # 1~5페이지 중 위치한 곳
page = 1  # 현재 페이지 번호
list1 = []  # 결과물이 저장되는 리스트

while 1: # 무한반복
    try:
        try:
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
            # 이미지가 있는 경우 데이터 수집
            if img_element.is_displayed():
                # 플러스 이미지 클릭 
                driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img').click()
                # 열린 새로운 창으로 이동 
                driver.switch_to.window(driver.window_handles[-1])
                time.sleep(3) # 크롤링할 시간을 줌 

                title = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[1]/span/a').text  # 연수명
                content = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[2]/table/tbody/tr[3]/td').text  # 내용
                img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[2]/table/tbody/tr[2]/td/span[1]/img')
                score = img_element.get_attribute('alt')

                driver.close() # 창 닫음 
                driver.switch_to.window(driver.window_handles[0]) # 다시 현재의 창으로 이동 

                # 등록일은 구성이 밖에서 수집하는게 더 좋아서 밖에서 수집 
                date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
                date = date_.split('\n')[1]

                # 수집한 데이터를 리스트에 넣음 
                list1.append([title, content, score, date])

        except NoSuchElementException:
            # 이미지가 없는 경우 데이터 수집
                review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
                title = review.split('\n\n')[0]  # 연수명
                content = review.split('\n\n')[1].split('\n')[1]  # 내용
                img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
                score = img_element.get_attribute('alt') # 점수
                date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
                date = date_.split('\n')[1] # 등록일 
                list1.append([title, content, score, date])

        finally:
            # 다음 인덱스로 이동
            ind += 1
        
        # 쭉 가져오다가. 10페이지를 다 돌았으면, 다음페이지를 누르고 아니면 계속 페이지 이동을 해라 
    except: 
        # 위치를(no.) 10번을 다 돌았는지 확인. 
        # 다 돌았으면 다음 페이지 버튼을 클릭하고 페이지번호와 인덱스를 다시 1로 바꾸고 페이지 번호는 하나 늘림
        # 10페이지 단위마다 다음 페이지 버튼 누르기
        if no >= 10:
            driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/div[3]/a[12]/img').click()
            no = 1
            ind = 1
            page += 1
            continue
            
        # 위치를 다 돌지않았으면 페이지 번호를 클릭함 
        elif driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/div[3]/a[{no+2}]').is_displayed():
            no += 1
            driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/div[3]/a[{no+1}]').click()
            ind = 1
            page += 1
            continue
        
        # 더이상 이동할수 없을 경우 종료
        # = 다음페이지도 없고 10배수도 아닐때 종료 
        else:
            break
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[110], line 18
#      16 time.sleep(3) # 크롤링할 시간을 줌
# ---> 18 title = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[1]/span/a').text  # 연수명
#      19 content = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[2]/table/tbody/tr[3]/td').text  # 내용
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:740, in WebDriver.find_element(self, by, value)
#     738     value = f'[name="{value}"]'
# --> 740 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mainForm"]/div[1]/span/a"}
#   (Session info: chrome=115.0.5790.110); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00F6A813+48355]
# 	(No symbol) [0x00EFC4B1]
# 	(No symbol) [0x00E05358]
# 	(No symbol) [0x00E309A5]
# 	(No symbol) [0x00E30B3B]
# 	(No symbol) [0x00E5E232]
# 	(No symbol) [0x00E4A784]
# 	(No symbol) [0x00E5C922]
# 	(No symbol) [0x00E4A536]
# 	(No symbol) [0x00E282DC]
# 	(No symbol) [0x00E293DD]
# 	GetHandleVerifier [0x011CAABD+2539405]
# 	GetHandleVerifier [0x0120A78F+2800735]
# 	GetHandleVerifier [0x0120456C+2775612]
# 	GetHandleVerifier [0x00FF51E0+616112]
# 	(No symbol) [0x00F05F8C]
# 	(No symbol) [0x00F02328]
# 	(No symbol) [0x00F0240B]
# 	(No symbol) [0x00EF4FF7]
# 	BaseThreadInitThunk [0x77137D59+25]
# 	RtlInitializeExceptionChain [0x77E7B79B+107]
# 	RtlClearBits [0x77E7B71F+191]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[110], line 35
#      33 except NoSuchElementException:
#      34     # 이미지가 없는 경우 데이터 수집
# ---> 35         review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
#      36         title = review.split('\n\n')[0]  # 연수명
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:740, in WebDriver.find_element(self, by, value)
#     738     value = f'[name="{value}"]'
# --> 740 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mainForm"]/table/tbody/tr[8]/td[2]/a"}
#   (Session info: chrome=115.0.5790.110); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00F6A813+48355]
# 	(No symbol) [0x00EFC4B1]
# 	(No symbol) [0x00E05358]
# 	(No symbol) [0x00E309A5]
# 	(No symbol) [0x00E30B3B]
# 	(No symbol) [0x00E5E232]
# 	(No symbol) [0x00E4A784]
# 	(No symbol) [0x00E5C922]
# 	(No symbol) [0x00E4A536]
# 	(No symbol) [0x00E282DC]
# 	(No symbol) [0x00E293DD]
# 	GetHandleVerifier [0x011CAABD+2539405]
# 	GetHandleVerifier [0x0120A78F+2800735]
# 	GetHandleVerifier [0x0120456C+2775612]
# 	GetHandleVerifier [0x00FF51E0+616112]
# 	(No symbol) [0x00F05F8C]
# 	(No symbol) [0x00F02328]
# 	(No symbol) [0x00F0240B]
# 	(No symbol) [0x00EF4FF7]
# 	BaseThreadInitThunk [0x77137D59+25]
# 	RtlInitializeExceptionChain [0x77E7B79B+107]
# 	RtlClearBits [0x77E7B71F+191]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[110], line 61
#      58     continue
#      60 # 위치를 다 돌지않았으면 페이지 번호를 클릭함
# ---> 61 elif driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/div[3]/a[{no+2}]').is_displayed():
#      62     no += 1
#      63     driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/div[3]/a[{no+1}]').click()
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:740, in WebDriver.find_element(self, by, value)
#     737     by = By.CSS_SELECTOR
#     738     value = f'[name="{value}"]'
# --> 740 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#     348     return response
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mainForm"]/div[3]/a[7]"}
#   (Session info: chrome=115.0.5790.110); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00F6A813+48355]
# 	(No symbol) [0x00EFC4B1]
# 	(No symbol) [0x00E05358]
# 	(No symbol) [0x00E309A5]
# 	(No symbol) [0x00E30B3B]
# 	(No symbol) [0x00E5E232]
# 	(No symbol) [0x00E4A784]
# 	(No symbol) [0x00E5C922]
# 	(No symbol) [0x00E4A536]
# 	(No symbol) [0x00E282DC]
# 	(No symbol) [0x00E293DD]
# 	GetHandleVerifier [0x011CAABD+2539405]
# 	GetHandleVerifier [0x0120A78F+2800735]
# 	GetHandleVerifier [0x0120456C+2775612]
# 	GetHandleVerifier [0x00FF51E0+616112]
# 	(No symbol) [0x00F05F8C]
# 	(No symbol) [0x00F02328]
# 	(No symbol) [0x00F0240B]
# 	(No symbol) [0x00EF4FF7]
# 	BaseThreadInitThunk [0x77137D59+25]
# 	RtlInitializeExceptionChain [0x77E7B79B+107]
# 	RtlClearBits [0x77E7B71F+191]

# %%
list1 = pd.DataFrame(list1)
list1
# Out:
#                                  0  \
# 0              같이 읽고 함께 나누는 독서수업방법
# 1                           강의의 품격
# 2                신병주 교수의 왕으로 산다는 것
# 3     15시간 메디컬 콘서트 1탄 - 현대인의 만성 질병
# 4                      정훈쌤의 뚝딱 칼림바
# ...                            ...
# 2142  15시간 메디컬 콘서트 2탄 - 여성 건강 프로젝트
# 2143  15시간 메디컬 콘서트 1탄 - 현대인의 만성 질병
# 2144   15시간 교육과정을 뒤집다! 백워드 통합단원 설계
# 2145              독립운동 현장읽기 - 의병전쟁
# 2146            독립운동 현장읽기 - 구국계몽운동
#
#                                                       1   2           3
# 0     아이를 키우며 그림책과 동화책에 관심을 갖게 되었다.\n감동적이고 재미있는 책들을 ...  5점  2023.07.28
# 1     비추천합니다. 새로울 것 없는 내용과 화질 안 좋은 것은 참겠는데 음향은 정말 괴로...  3점  2023.07.27
# 2     조선왕들의 역사를 통하여 현재를 묻는 거울이 된다.\n균형있는 강의 내용과 치우침이...  5점  2023.07.27
# 3                      잘못 알고 있던 의학 상식들을 제대로 알 수 있어 좋았어요  5점  2023.07.27
# 4     칼림바 연수에서 칼림바와 악보를 선물로 받았습니다. 학생들이 음악 강사와 칼림바 수...  5점  2023.07.26
# ...                                                 ...  ..         ...
# 2142                           평소 꾸준한 건강관리의 필요성을 느꼈습니다.  5점  2021.06.21
# 2143                           평소 꾸준한 건강관리의 필요성을 느꼈습니다.  5점  2021.06.21
# 2144                              그동안의 수업을 되돌아보게 되었습니다.  5점  2021.06.21
# 2145  연수 내용도 훌륭했지만 무엇보다 그 내용을 전달하시는 분들의 스토리텔링 능력에 감탄...  5점  2021.06.21
# 2146  연수 내용도 훌륭했지만 무엇보다 그 내용을 전달하시는 분들의 스토리텔링 능력에 감탄...  5점  2021.06.21
#
# [2147 rows x 4 columns]

# %%
list1.to_csv('t_data_1.csv')

# %%
# 연도를 2023년, 2022년만 하기로 함

# %%
ind = 1  # 현재 복사한 순서 # 인덱스
no = 1  # 1~5페이지 중 위치한 곳
page = 1  # 현재 페이지 번호
list2023_22 = []  # 결과물이 저장되는 리스트

while 1: # 무한반복
    try:
        try:
            img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img')
            # 이미지가 있는 경우 데이터 수집
            if img_element.is_displayed():
                
                date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
                date = date_.split('\n')[1] # 등록일
                
                date_year = date.split('.')[0] # 연도만 추출 
                
                if date_year == '2021':
                    break
                else:
                    # 플러스 이미지 클릭 
                    driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a/img').click()
                    # 열린 새로운 창으로 이동 
                    driver.switch_to.window(driver.window_handles[-1])
                    time.sleep(1) # 크롤링할 시간을 줌 

                    title = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[1]/span/a').text  # 연수명
                    content = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[2]/table/tbody/tr[3]/td').text  # 내용
                    img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/div[2]/table/tbody/tr[2]/td/span[1]/img')
                    score = img_element.get_attribute('alt')

                    driver.close() # 창 닫음 
                    driver.switch_to.window(driver.window_handles[0]) # 다시 현재의 창으로 이동 

                    # 수집한 데이터를 리스트에 넣음 
                    list2023_22.append([title, content, score, date])    

        except NoSuchElementException:
            # 이미지가 없는 경우 데이터 수집
            
                date_ = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]').text
                date = date_.split('\n')[1] # 등록일 
                date_year = date.split('.')[0] # 연도만 추출 
                
                if date_year == '2021':
                    break
                else:
                    review = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[2]/a').text
                    title = review.split('\n\n')[0]  # 연수명
                    content = review.split('\n\n')[1].split('\n')[1]  # 내용
                    img_element = driver.find_element(by='xpath', value=f'//*[@id="mainForm"]/table/tbody/tr[{ind}]/td[3]/img')
                    score = img_element.get_attribute('alt') # 점수

                    list2023_22.append([title, content, score, date])

        finally:
            # 다음 인덱스로 이동
            ind += 1
        
        # 쭉 가져오다가. 10페이지를 다 돌았으면, 다음페이지를 누르고 아니면 계속 페이지 이동을 해라 
    except: 
        # 위치를(no.) 10번을 다 돌았는지 확인. 
        # 다 돌았으면 다음 페이지 버튼을 클릭하고 페이지번호와 인덱스를 다시 1로 바꾸고 페이지 번호는 하나 늘림
        # 10페이지 단위마다 다음 페이지 버튼 누르기
        if no >= 10:
            driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/div[3]/a[12]/img').click()
            no = 1
            ind = 1
            page += 1
            continue
            
        # 위치를 다 돌지않았으면 페이지 번호를 클릭함 
        elif driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/div[3]/a[{no+2}]').is_displayed():
            no += 1
            driver.find_element(by='xpath',value = f'//*[@id="mainForm"]/div[3]/a[{no+1}]').click()
            ind = 1
            page += 1
            continue
        
        # 더이상 이동할수 없을 경우 종료
        # = 다음페이지도 없고 10배수도 아닐때 종료 
        else:
            break

# %%
list2023_22 = pd.DataFrame(list2023_22)

# %%
list2023_22.to_csv('t_data_2.csv')
