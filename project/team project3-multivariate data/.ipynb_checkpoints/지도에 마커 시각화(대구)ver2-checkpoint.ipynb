# %%
# 패키지 불러오기
import pandas as pd
import folium
import json
import requests
import time

# %%
# 주소 정보 csv 불러오기 

hb = pd.read_csv('./data/(최종)해법수학결과.csv')
mirae = pd.read_csv('./data/(최최종)미래엔수학결과_주소수정.csv')

# %% [markdown]
# ### 스마트해법과 미래엔수학 대구 위치만 출력

# %%
hb['도'] = hb['주소'].apply(lambda x: x.split()[0])
hb['시'] = hb['주소'].apply(lambda x: x.split()[1])
hb['구'] = hb['주소'].apply(lambda x: x.split()[2])

# %%
hb_dae = hb[hb['도'] == '대구']
hb_dae.reset_index(drop = True, inplace=True)
hb_dae
# Out:
#               지점                                           주소   도    시       구
# 0     구암 화성그랜드 점                         대구 북구 구암로65길 6 (구암동)  대구   북구  구암로65길
# 1    대구 AK그랑폴리스점          대구 달서구 월배로11길 33 (유천동, 진천역 AK그랑폴리스)  대구  달서구  월배로11길
# 2        대구 경운1점                              대구 서구 내당동 258-9  대구   서구     내당동
# 3       대구 고성달성점               대구 북구 칠성남로 101 (칠성동2가, 칠성휴먼시아)  대구   북구    칠성남로
# 4   대구 구암엘리트해법수학                 대구 북구 팔거천동로 52 (구암동, 칠곡미래타운)  대구   북구   팔거천동로
# ..           ...                                          ...  ..  ...     ...
# 78      동대구지사직영점                             대구 수성구 중동 551-85  대구  수성구      중동
# 79    북구 그린빌6단지점          대구 북구 도남길 76 (국우동, 힐스테이트 데시앙 도남1단지)  대구   북구     도남길
# 80     사수 서한이다음점                  대구 북구 한강로 17 (사수동, 금호서한이다음)  대구   북구     한강로
# 81      서재 아이위시점  대구 달성군 다사읍 서재로7길 25 (서재리, 에코폴리스 동화 아이위시 3차)  대구  달성군     다사읍
# 82       중동스마트해법                             대구 수성구 수성로41길 32  대구  수성구  수성로41길
#
# [83 rows x 5 columns]

# %%
hb_dae.iloc[8, 1] = '대구시 중구 재마루길 77'
# Out:
# C:\Users\BIG2-003-008\AppData\Local\Temp\ipykernel_6192\2939369812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hb_dae.iloc[8, 1] = '대구시 중구 재마루길 77'

# %%
mirae
# Out:
#                지점                       주소
# 0      미래엔매쓰팜수학학원         서울 은평구 진관1로 21-9
# 1       가야학원 성수교실            서울 성동구 성수일로 1
# 2          가양한보교실            서울 강서구 허준로 76
# 3         가재울연가교실          서울 서대문구 증가로 193
# 4        가재울DMC수학           서울 서대문구 응암로 41
# ...           ...                      ...
# 1083      중앙에이스교실    제주특별자치도 제주시 서사로18길 33
# 1084       지성수학교실  제주특별자치도 서귀포시 중앙로195번길 2
# 1085     하귀아이클릭교실   제주특별자치도 제주시 애월읍 하귀로 48
# 1086       하귀휴먼시아  제주특별자치도 제주시 애월읍 하귀9길 34
# 1087  한라한솔플러스수학교실    제주특별자치도 제주시 연화로3길 4-1
#
# [1088 rows x 2 columns]

# %%
mirae['도'] = mirae['주소'].apply(lambda x: x.split()[0])

# %%
mirae['시'] = mirae['주소'].apply(lambda x: x.split()[1] if x.split()[0] == '대구' else "")

# 35         안심교실           대구 동구 신서동 548-5  대구   동구        신서동
# 36      영무예다음교실  대구 달성군 구지면 국가산단서로84길 118  대구  달성군        구지면
# 37        우미린교실     대구 달성군 유가읍 테크노북로9길 42  대구  달성군        유가읍
# 38         월배교실            대구 달서구 진천동 263  대구  달서구        진천동
# 39      월암E편한교실            대구 달서구 월성로 132  대구  달서구        월성로
# 40         월촌교실            대구 달서구 상인서로 46  대구  달서구       상인서로
# 41         이곡교실            대구 달서구 당산로 215  대구  달서구        당산로
# 42     일등 수학 교실            대구 달서구 달서대로 67  대구  달서구       달서대로
# 43      제네스월촌교실          대구 달서구 월배로68길 18  대구  달서구     월배로68길
# 44    제일풍경채2차교실      대구 달성군 유가면 테크노대로 165  대구  달성군        유가면
# 45         진천교실          대구 달서구 진천로3길 112  대구  달서구      진천로3길
# 46  침산 한라스카이빌교실            대구 북구 침산로22길 5  대구   북구     침산로22길
# 47        풍경채교실         대구 달성군 현풍면 중리 484  대구  달성군        현풍면
# 48        한샘초교실          대구 달서구 대천동 473-1  대구  달서구        대천동
# 49       한솔옥포교실         대구 달성군 옥포읍 돌미로 50  대구  달성군        옥포읍
# 50     한일유앤아이교실            대구 수성구 고산로 162  대구  수성구        고산로
# 51       혁신새론교실           대구 동구 과학로13길 14  대구   동구     과학로13길
# 52         화남교실         대구 달성군 화원읍 명곡로 11  대구  달성군        화원읍
# 53       화성파크교실            대구 달서구 월곡로 320  대구  달서구        월곡로
# 54         효목교실              대구 동구 효목로 69  대구   동구        효목로

# %% [markdown]
# ### 위경도 변경

# %%
# https://developers.kakao.com/docs/latest/ko/local/dev-guide
# 카카오 REST API

def get_location(address):
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + address
    headers = {"Authorization": "KakaoAK 키번호"} # 키번호는 개인정보라 삭제. 개인적으로 발급 후 사용 권장 
    api_json = json.loads(str(requests.get(url,headers=headers).text))
    return api_json

# %%
get_location("서울특별시 금천구 디지털로9길 23")
# Out:
# {'documents': [{'address': {'address_name': '서울 금천구 가산동 60-52',
#     'b_code': '1154510100',
#     'h_code': '1154551000',
#     'main_address_no': '60',
#     'mountain_yn': 'N',
#     'region_1depth_name': '서울',
#     'region_2depth_name': '금천구',
#     'region_3depth_h_name': '가산동',
#     'region_3depth_name': '가산동',
#     'sub_address_no': '52',
#     'x': '126.886476789522',
#     'y': '37.478720573213'},
#    'address_name': '서울 금천구 디지털로9길 23',
#    'address_type': 'ROAD_ADDR',
#    'road_address': {'address_name': '서울 금천구 디지털로9길 23',
#     'building_name': '마리오2 패션타워',
#     'main_building_no': '23',
#     'region_1depth_name': '서울',
#     'region_2depth_name': '금천구',
#     'region_3depth_name': '가산동',
#     'road_name': '디지털로9길',
#     'sub_building_no': '',
#     'underground_yn': 'N',
#     'x': '126.886476789522',
#     'y': '37.478720573213',
#     'zone_no': '08511'},
#    'x': '126.886476789522',
#    'y': '37.478720573213'}],
#  'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}

# %%
# 위경도 변환 모델

def result_location(data, i):
    api_json = get_location(data['주소'][i])
    if api_json['documents']:
        address = api_json['documents'][0]['address']
        data.loc[i,'x'] = float(address['y'])       
        data.loc[i,'y'] = float(address['x']) 
    else:
        data.loc[i,'x'], data.loc[i,'y'] = None, None

# %%
# 실행부 - 해법

i = 0
while i<=len(hb_dae['주소'])-1:
    try:
        result_location(hb_dae, i)
        i+=1
    except:
        result_location(hb_dae, i)
        i+=1
# Out:
# C:\Users\BIG2-003-008\AppData\Local\Temp\ipykernel_6192\1004955862.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[i,'x'] = float(address['y'])
# C:\Users\BIG2-003-008\AppData\Local\Temp\ipykernel_6192\1004955862.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[i,'y'] = float(address['x'])

# %%
# 실행부 - 미래엔

i = 0
while i<=len(mirae_dae['주소'])-1:
    try:
        result_location(mirae_dae, i)
        i+=1
    except:
        i+=1
# Out:
# C:\Users\BIG2-003-008\AppData\Local\Temp\ipykernel_6192\1004955862.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[i,'x'] = float(address['y'])
# C:\Users\BIG2-003-008\AppData\Local\Temp\ipykernel_6192\1004955862.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[i,'y'] = float(address['x'])

# %%
hb_dae = hb_dae.drop(columns = {'도', '시', '구'})

# %%
mirae_dae = mirae_dae.drop(columns = {'도', '시', '구'})

# %%
hb_dae
# Out:
#               지점                                           주소          x  \
# 0     구암 화성그랜드 점                         대구 북구 구암로65길 6 (구암동)  35.940779
# 1    대구 AK그랑폴리스점          대구 달서구 월배로11길 33 (유천동, 진천역 AK그랑폴리스)  35.814725
# 2        대구 경운1점                              대구 서구 내당동 258-9  35.860806
# 3       대구 고성달성점               대구 북구 칠성남로 101 (칠성동2가, 칠성휴먼시아)  35.878626
# 4   대구 구암엘리트해법수학                 대구 북구 팔거천동로 52 (구암동, 칠곡미래타운)  35.928511
# ..           ...                                          ...        ...
# 78      동대구지사직영점                             대구 수성구 중동 551-85  35.840882
# 79    북구 그린빌6단지점          대구 북구 도남길 76 (국우동, 힐스테이트 데시앙 도남1단지)  35.954588
# 80     사수 서한이다음점                  대구 북구 한강로 17 (사수동, 금호서한이다음)  35.897381
# 81      서재 아이위시점  대구 달성군 다사읍 서재로7길 25 (서재리, 에코폴리스 동화 아이위시 3차)  35.870815
# 82       중동스마트해법                             대구 수성구 수성로41길 32  35.844724
#
#              y
# 0   128.569107
# 1   128.516612
# 2   128.553732
# 3   128.591871
# 4   128.555485
# ..         ...
# 78  128.608378
# 79  128.582610
# 80  128.512105
# 81  128.489694
# 82  128.610734
#
# [83 rows x 4 columns]

# %%
mirae_dae
# Out:
#              지점                        주소          x           y
# 0          각산교실             대구 동구 경안로 820  35.875361  128.714301
# 1        골드파크교실            대구 수성구 청수로 257  35.841338  128.634771
# 2        글맥수학교실       대구 달성군 논공읍 논공로9길 66  35.730486  128.442622
# 3     꿈지담대신자이교실          대구 중구 달구벌대로 1955  35.863867  128.577719
# 4          남산교실              대구 중구 남산로 73  35.862279  128.582133
# 46  침산 한라스카이빌교실            대구 북구 침산로22길 5  35.886099  128.591275
# 47        풍경채교실         대구 달성군 현풍면 중리 484  35.693947  128.454336
# 48        한샘초교실          대구 달서구 대천동 473-1  35.816014  128.519735
# 49       한솔옥포교실         대구 달성군 옥포읍 돌미로 50  35.779403  128.439666
# 50     한일유앤아이교실            대구 수성구 고산로 162  35.846313  128.707357
# 51       혁신새론교실           대구 동구 과학로13길 14  35.885301  128.717613
# 52         화남교실         대구 달성군 화원읍 명곡로 11  35.798757  128.498647
# 53       화성파크교실            대구 달서구 월곡로 320  35.823583  128.534298
# 54         효목교실              대구 동구 효목로 69  35.879282  128.641073

# %%
# 대구 초등학교 데이터 
# 출처: 공공데이터포털(대구광역시교육청), https://www.data.go.kr/data/15015254/fileData.do


el = pd.read_csv('./data/대구광역시_초등학교현황.csv', encoding='cp949')
el
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 5
#       1 # 대구 초등학교 데이터
#       2 # 출처: 공공데이터포털(대구광역시교육청), https://www.data.go.kr/data/15015254/fileData.do
# ----> 5 el = pd.read_csv('./data/대구광역시_초등학교현황.csv', encoding='cp949')
#       6 el
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/대구광역시_초등학교현황.csv'

# %%
# 실행부 - 초등학교

i = 0
while i<=len(el['주소'])-1:
    try:
        result_location(el, i)
        i+=1
    except:
        i+=1

# %%
el

# %%
el[el['x'] != el['x']]

# %%
get_location('대구광역시 달서구 야외음악당로 15길')

# %%
el.iloc[179, 6] = '35.8440896878044'
el.iloc[179, 7] = '128.5496895918'

# %%
el['x'] = el['x'].astype(float)
el['y'] = el['y'].astype(float)

# %%
el.info()

# %% [markdown]
# ### 행정구역 경계
# * http://data.nsdi.go.kr/dataset/15144

# %%
# 행정구역 데이터
geo_path = ('./geo/LARD_ADM_SECT_SGG_대구.json')
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
# 빈 지도 생성
dae_aed = folium.Map(location=[35.8714354, 128.601445], zoom_start=11)

# %%
# 스마트해법 마커 추가 (빨간색)
for i in hb_dae.index:
    x = hb_dae.loc[i, 'x']
    y = hb_dae.loc[i, 'y']

    marker = folium.CircleMarker(location=[x, y],
                                  radius=5, line_color='red', fill_color='red', fill_opacity=1)
    marker.add_to(dae_aed)

# 미래엔수학 마커 추가 (파란색)
for i in mirae_dae.index:
    x = mirae_dae.loc[i, 'x']
    y = mirae_dae.loc[i, 'y']

    marker = folium.CircleMarker(location=[x, y],
                                  radius=5, line_color='blue', fill_color='blue', fill_opacity=1)
    marker.add_to(dae_aed)

# 초등학교 마커 추가 (노란색)
for i in el.index:
    x = el.loc[i, 'x']
    y = el.loc[i, 'y']

    marker = folium.CircleMarker(location=[x, y],
                                  radius=5, line_color='yellow', fill_color='yellow', fill_opacity=1)
    marker.add_to(dae_aed)

# 대구 정보 표기
folium.GeoJson(geo_str, name='json_data').add_to(dae_aed)

# 지도 저장 및 표시
dae_aed.save('./dae_aed.html')
dae_aed
