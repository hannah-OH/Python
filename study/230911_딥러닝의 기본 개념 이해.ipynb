# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.13.0

# %%
import torch

# %%
print(torch.__version__)
# Out:
# 1.12.1

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,50,50)
y = x + np.random.normal(0,1,50)

# %%
plt.scatter(x,y)

# %%
epochs = 10
learning_rate = 0.001

# %%
W = tf.Variable(0.)
b = tf.Variable(0.)

# %%
def linear_regression(x):
    y = W * x + b
    return y

# %%
def MSE(y_pred, y_true):
    return tf.reduce_mean(tf.square(y_pred - y_true))

# %%
for epoch in range(epochs):

    with tf.GradientTape() as tape:
        y_pred = linear_regression(x)
        cost = MSE(y_pred, y)

    W_grad, b_grad = tape.gradient(cost, [W,b])

    W.assign_sub(W_grad * learning_rate)
    b.assign_sub(b_grad * learning_rate)

    print(f"[Epoch {epoch+1}] cost value: {cost.numpy()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 12
#       9 W.assign_sub(W_grad * learning_rate)
#      10 b.assign_sub(b_grad * learning_rate)
# ---> 12 print(f"[Epoch {epoch+1}] loss value: {loss.numpy()}")
#
# NameError: name 'loss' is not defined

# %%
plt.scatter(x,y)
plt.plot(x, linear_regression(x), "r")
plt.show()

# %%
import tensorflow as tf
import numpy as np

# %%
x_train = [1, 2, 3]
y_train = [1, 2, 3]

# %%
sgd = tf.keras.optimizers.SGD(learning_rate=0.01)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1, input_dim=1, activation="linear"))
model.compile(loss="mse", optimizer=sgd)

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 0s 284ms/step - loss: 10.5020
# Epoch 2/5
# 1/1 [==============================] - 0s 5ms/step - loss: 8.3102
# Epoch 3/5
# 1/1 [==============================] - 0s 14ms/step - loss: 6.5777
# Epoch 4/5
# 1/1 [==============================] - 0s 6ms/step - loss: 5.2082
# Epoch 5/5
# 1/1 [==============================] - 0s 12ms/step - loss: 4.1257

# %%
print(model.predict(np.array([5])))
# Out:
# 1/1 [==============================] - 0s 67ms/step
# [[0.54650825]]

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[1], [2], [3]])

# %%
W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
epochs=5
optimizer=optim.SGD([W,b], lr=0.01)

# %% [markdown]
# # Single Layer Perceptron (SLP)

# %%
import numpy as np

# %% [markdown]
# ### AND 게이트

# %% [markdown]
# * 하나라도 0이면 0

# %%
# Not using

def AND_gate(x1, x2):
    w1, w2, theta = 0.5, 0.5, 0.7
    tmp = x1 * w1 + x2 * w2
    if tmp <= theta:
        return 0
    elif tmp > theta:
        return 1

# %%
# Using

def AND_np(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.7
    tmp = np.sum(w*x)+b
    if tmp <= 0:
        return 0
    else:
        return 1

# %% [markdown]
# ### NAND 게이트

# %% [markdown]
# * 하나라도 1이면 1

# %%
# Not using

def OR_gate(x1, x2):
    w1, w2, theta = 0.5, 0.5, 0.2
    tmp = x1 * w1 + x2 * w2
    if tmp <= theta:
        return 0
    elif tmp > theta:
        return 1

# %%
# Using

def OR_np(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.2
    tmp = np.sum(w * x) + b
    if tmp <= 0:
        return 0
    else:
        return 1
